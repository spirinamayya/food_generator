# %% [markdown]
# # GitHub publication — 2026-09-12 13:16:46 +0400
#
# **Intent:** Publish `food_generator` as a standalone repository while preserving the existing remote `main` history.

# %% [markdown]
# ## Method
# Initialize local `main`, add the exact HTTPS origin, fetch remote `main`, base the local branch on it, then inspect, validate, stage, commit, push normally, and verify all refs.

# %%
# Commands executed before publication (shell)
git init -b main
git remote add origin https://github.com/spirinamayya/food_generator.git
git fetch origin main
git reset --mixed origin/main
git log --oneline -10
git remote -v
# Out:
# Initialized empty Git repository in food_generator/.git/
# Fetched main -> origin/main
# c50c802 Initial commit
# origin https://github.com/spirinamayya/food_generator.git (fetch)
# origin https://github.com/spirinamayya/food_generator.git (push)

# %% [markdown]
# ## Interpretation
# The standalone repository was initialized and linked to the intended origin. The fetched root commit `c50c802` is available as the base, so publication can preserve the remote README and history without force-pushing.
